# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("/Users/hannahkollmann/Desktop/heart_disease_dataset.csv")
application_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Age  Gender  Cholesterol  Blood Pressure  \
# 0             0           0   75  Female          228             119
# 1             1           1   48    Male          204             165
# 2             2           2   53    Male          234              91
# 3             3           3   69  Female          192              90
# 4             4           4   62  Female          172             163
#
#    Heart Rate  Smoking Alcohol Intake  Exercise Hours Family History Diabetes  \
# 0          66  Current          Heavy               1             No       No
# 1          62  Current            NaN               5             No       No
# 2          67    Never          Heavy               3            Yes       No
# 3          72  Current            NaN               4             No      Yes
# 4          93    Never            NaN               6             No      Yes
#
#   Obesity  Stress Level  Blood Sugar Exercise Induced Angina  \
# 0     Yes             8          119                     Yes
# 1      No             9           70                     Yes
# 2     Yes             5          196                     Yes
# 3      No             7          107                     Yes
# 4      No             2          183                     Yes
#
#     Chest Pain Type  Heart Disease
# 0   Atypical Angina              1
# 1    Typical Angina              0
# 2   Atypical Angina              1
# 3  Non-anginal Pain              0
# 4      Asymptomatic              0

# %%
# Drop the Unnamed columns to optimize model 
application_df = application_df.drop(['Unnamed: 0.1', 'Unnamed: 0'],axis=1)
application_df.head()
# Out:
#    Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0   75  Female          228             119          66  Current
# 1   48    Male          204             165          62  Current
# 2   53    Male          234              91          67    Never
# 3   69  Female          192              90          72  Current
# 4   62  Female          172             163          93    Never
#
#   Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0          Heavy               1             No       No     Yes
# 1            NaN               5             No       No      No
# 2          Heavy               3            Yes       No     Yes
# 3            NaN               4             No      Yes      No
# 4            NaN               6             No      Yes      No
#
#    Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0             8          119                     Yes   Atypical Angina
# 1             9           70                     Yes    Typical Angina
# 2             5          196                     Yes   Atypical Angina
# 3             7          107                     Yes  Non-anginal Pain
# 4             2          183                     Yes      Asymptomatic
#
#    Heart Disease
# 0              1
# 1              0
# 2              1
# 3              0
# 4              0

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# Age                         55
# Gender                       2
# Cholesterol                200
# Blood Pressure              90
# Heart Rate                  40
# Smoking                      3
# Alcohol Intake               2
# Exercise Hours              10
# Family History               2
# Diabetes                     2
# Obesity                      2
# Stress Level                10
# Blood Sugar                130
# Exercise Induced Angina      2
# Chest Pain Type              4
# Heart Disease                2
# dtype: int64
